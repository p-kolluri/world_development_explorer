# %% [markdown]
# # ⚡ Factors effecting the environment and contributing to climate change.

# %% [markdown]
# Name : Praharsh Kolluri.
#
# Let us look at some of the factors effecting and contributing to climate change. In this notebook we will be looking at the following factors:
#
# ☁ CO2 Emissions.
#
# 🌳 Forest cover.
#
# 🏢 Urban land area.
#
# Primarily we will be analysing if these three factors are related, such as is less forest cover or decreasing forest cover increase CO2 emissions? does increasing urban land area increase CO2 emissions? Let us compare the data.

# %% [markdown]
# # ⚡ Importing Data.

# %%
import pandas as pd
import plotly
import plotly.express as px

Data_URL = "https://raw.githubusercontent.com/p-kolluri/world_development_explorer/main/wdi_data%20(2).csv"

# %%
df = pd.read_csv(Data_URL)
df.head()
# Out:
#    Unnamed: 0  Year   value       indicator Country Code Country Name  \
# 0           0  1990  2960.0  EN.ATM.CO2E.KT          AFG  Afghanistan
# 1           1  1991  2740.0  EN.ATM.CO2E.KT          AFG  Afghanistan
# 2           2  1992  1430.0  EN.ATM.CO2E.KT          AFG  Afghanistan
# 3           3  1993  1360.0  EN.ATM.CO2E.KT          AFG  Afghanistan
# 4           4  1994  1300.0  EN.ATM.CO2E.KT          AFG  Afghanistan
#
#        Region Income Group Lending Type
# 0  South Asia   Low income          IDA
# 1  South Asia   Low income          IDA
# 2  South Asia   Low income          IDA
# 3  South Asia   Low income          IDA
# 4  South Asia   Low income          IDA

# %% [markdown]
# # ⚡ CO2 Emissions.

# %%
df_1990_co2 = df.query("Year == 1990").query("indicator == 'EN.ATM.CO2E.KT'")
df_1990_co2.rename(columns = {"value":"EN.ATM.CO2E.KT"}, inplace=True)
df_1990_co2.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_1990_co2.reset_index(drop=True,inplace=True)

df_1990_co2
# Out:
#    Unnamed: 0  Year  EN.ATM.CO2E.KT Country Code   Country Name
# 0           0  1990          2960.0          AFG    Afghanistan
# 1          29  1990         11520.0          BGD     Bangladesh
# 2          58  1990           130.0          BTN         Bhutan
# 3          87  1990        419120.0          CAN         Canada
# 4         116  1990        562480.0          IND          India
# 5         145  1990           160.0          MDV       Maldives
# 6         174  1990           940.0          NPL          Nepal
# 7         203  1990         61050.0          PAK       Pakistan
# 8         232  1990          3840.0          LKA      Sri Lanka
# 9         261  1990       4844990.0          USA  United States

# %%
fig = px.bar(
    df_1990_co2, 
    x="EN.ATM.CO2E.KT",
    labels={"EN.ATM.CO2E.KT":"1990 CO2 emissions (kt)"},
    color="Country Name",
    height=800,
    title='Worldwide distribution of CO2 emissions, 1990',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="aaa8ca10-b741-433c-9c41-5c1f12de1960" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaa8ca10-b741-433c-9c41-5c1f12de1960")) {                    Plotly.newPlot(                        "aaa8ca10-b741-433c-9c41-5c1f12de1960",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Afghanistan<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"h","showlegend":true,"textposition":"auto","x":[2960.0],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[11520.0],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bhutan<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bhutan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bhutan","offsetgroup":"Bhutan","orientation":"h","showlegend":true,"textposition":"auto","x":[130.0],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[419120.0],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[562480.0],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[160.0],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Nepal<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"h","showlegend":true,"textposition":"auto","x":[940.0],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[61050.0],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"h","showlegend":true,"textposition":"auto","x":[3840.0],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=United States<br>1990 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pattern": ...

# %%
df_2018_co2 = df.query("Year == 2018").query("indicator == 'EN.ATM.CO2E.KT'")
df_2018_co2.rename(columns = {"value":"EN.ATM.CO2E.KT"}, inplace=True)
df_2018_co2.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_2018_co2.reset_index(drop=True,inplace=True)

df_2018_co2
# Out:
#    Unnamed: 0  Year  EN.ATM.CO2E.KT Country Code   Country Name
# 0          28  2018          7440.0          AFG    Afghanistan
# 1          57  2018         82760.0          BGD     Bangladesh
# 2          86  2018          1380.0          BTN         Bhutan
# 3         115  2018        574400.0          CAN         Canada
# 4         144  2018       2434520.0          IND          India
# 5         173  2018          1910.0          MDV       Maldives
# 6         202  2018         12030.0          NPL          Nepal
# 7         231  2018        208370.0          PAK       Pakistan
# 8         260  2018         21630.0          LKA      Sri Lanka
# 9         289  2018       4981300.0          USA  United States

# %%
fig = px.bar(
    df_2018_co2, 
    x="EN.ATM.CO2E.KT",
    labels={"EN.ATM.CO2E.KT":"2018 CO2 emissions (kt)"},
    color="Country Name",
    height=800,
    title='Worldwide distribution of CO2 emissions, 2018',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2c9950fa-21d5-4fcc-806e-7057ff8dfd28" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c9950fa-21d5-4fcc-806e-7057ff8dfd28")) {                    Plotly.newPlot(                        "2c9950fa-21d5-4fcc-806e-7057ff8dfd28",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Afghanistan<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"h","showlegend":true,"textposition":"auto","x":[7440.0],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[82760.0],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bhutan<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bhutan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bhutan","offsetgroup":"Bhutan","orientation":"h","showlegend":true,"textposition":"auto","x":[1380.0],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[574400.0],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[2434520.0],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[1910.0],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Nepal<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"h","showlegend":true,"textposition":"auto","x":[12030.0],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[208370.0],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"h","showlegend":true,"textposition":"auto","x":[21630.0],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=United States<br>2018 CO2 emissions (kt)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pa ...

# %% [markdown]
# # ⚡ Forest Cover.

# %%
df_1990_forest = df.query("Year == 1990").query("indicator == 'AG.LND.FRST.K2'")
df_1990_forest.rename(columns = {"value":"AG.LND.FRST.K2"}, inplace=True)
df_1990_forest.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_1990_forest.reset_index(drop=True,inplace=True)

df_1990_forest
# Out:
#     Unnamed: 0  Year  AG.LND.FRST.K2 Country Code   Country Name
# 0          314  1990         12084.4          AFG    Afghanistan
# 1          343  1990         19203.3          BGD     Bangladesh
# 2          372  1990            10.0          BMU        Bermuda
# 3          401  1990         25067.2          BTN         Bhutan
# 4          430  1990       3482729.3          CAN         Canada
# 5          459  1990        639380.0          IND          India
# 6          488  1990             8.2          MDV       Maldives
# 7          517  1990         56720.0          NPL          Nepal
# 8          546  1990          1447.4          PAK       Pakistan
# 9          575  1990         23503.3          LKA      Sri Lanka
# 10         604  1990       3024500.0          USA  United States

# %%
fig = px.bar(
    df_1990_forest, 
    x="AG.LND.FRST.K2",
    labels={"AG.LND.FRST.K2":"1990 Forest area (sq.km)"},
    color="Country Name",
    height=800,
    title='Worldwide Forest area (sq.km), 1990',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="033929a7-1677-42be-af91-ddd4c3a7471b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("033929a7-1677-42be-af91-ddd4c3a7471b")) {                    Plotly.newPlot(                        "033929a7-1677-42be-af91-ddd4c3a7471b",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Afghanistan<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"h","showlegend":true,"textposition":"auto","x":[12084.4],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[19203.3],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bermuda<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"h","showlegend":true,"textposition":"auto","x":[10.0],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bhutan<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bhutan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bhutan","offsetgroup":"Bhutan","orientation":"h","showlegend":true,"textposition":"auto","x":[25067.2],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[3482729.3],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[639380.0],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[8.2],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Nepal<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"h","showlegend":true,"textposition":"auto","x":[56720.0],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[1447.4],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>1990 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FECB52","pattern":{"sha ...

# %%
df_2018_forest = df.query("Year == 2018").query("indicator == 'AG.LND.FRST.K2'")
df_2018_forest.rename(columns = {"value":"AG.LND.FRST.K2"}, inplace=True)
df_2018_forest.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_2018_forest.reset_index(drop=True,inplace=True)

df_2018_forest
# Out:
#     Unnamed: 0  Year  AG.LND.FRST.K2 Country Code   Country Name
# 0          342  2018         12084.4          AFG    Afghanistan
# 1          371  2018         18834.0          BGD     Bangladesh
# 2          400  2018            10.0          BMU        Bermuda
# 3          429  2018         27211.2          BTN         Bhutan
# 4          458  2018       3470020.7          CAN         Canada
# 5          487  2018        716272.0          IND          India
# 6          516  2018             8.2          MDV       Maldives
# 7          545  2018         59620.3          NPL          Nepal
# 8          574  2018         38085.8          PAK       Pakistan
# 9          603  2018         21193.4          LKA      Sri Lanka
# 10         632  2018       3097950.0          USA  United States

# %%
fig = px.bar(
    df_2018_forest, 
    x="AG.LND.FRST.K2",
    labels={"AG.LND.FRST.K2":"2018 Forest area (sq.km)"},
    color="Country Name",
    height=800,
    title='Worldwide Forest area (sq.km), 2018',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9a6d7b7c-c7fb-4e5d-92fa-0c826ec46f9c" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a6d7b7c-c7fb-4e5d-92fa-0c826ec46f9c")) {                    Plotly.newPlot(                        "9a6d7b7c-c7fb-4e5d-92fa-0c826ec46f9c",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Afghanistan<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"h","showlegend":true,"textposition":"auto","x":[12084.4],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[18834.0],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bermuda<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"h","showlegend":true,"textposition":"auto","x":[10.0],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bhutan<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bhutan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bhutan","offsetgroup":"Bhutan","orientation":"h","showlegend":true,"textposition":"auto","x":[27211.2],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[3470020.7],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[716272.0],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[8.2],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Nepal<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"h","showlegend":true,"textposition":"auto","x":[59620.3],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[38085.8],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>2018 Forest area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FECB52","pattern":{"sh ...

# %% [markdown]
# # ⚡ Urban Land area.

# %%
df_1990_urban = df.query("Year == 1990").query("indicator == 'AG.LND.TOTL.UR.K2'")
df_1990_urban.rename(columns = {"value":"AG.LND.TOTL.UR.K2"}, inplace=True)
df_1990_urban.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_1990_urban.reset_index(drop=True,inplace=True)

df_1990_urban
# Out:
#    Unnamed: 0  Year  AG.LND.TOTL.UR.K2 Country Code   Country Name
# 0         290  1990       11125.391600          BGD     Bangladesh
# 1         293  1990          38.615192          BMU        Bermuda
# 2         296  1990      126511.164100          CAN         Canada
# 3         299  1990      222688.234400          IND          India
# 4         302  1990           0.000000          MDV       Maldives
# 5         305  1990       35871.941410          PAK       Pakistan
# 6         308  1990        4016.146484          LKA      Sri Lanka
# 7         311  1990      802053.592300          USA  United States

# %%
fig = px.bar(
    df_1990_urban, 
    x="AG.LND.TOTL.UR.K2",
    labels={"AG.LND.TOTL.UR.K2":"1990 Urban land area (sq.km)"},
    color="Country Name",
    height=800,
    title='Worldwide Urban land area (sq.km), 1990',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dab85048-315f-459b-82c6-90e9edd22e8a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dab85048-315f-459b-82c6-90e9edd22e8a")) {                    Plotly.newPlot(                        "dab85048-315f-459b-82c6-90e9edd22e8a",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[11125.3916],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bermuda<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"h","showlegend":true,"textposition":"auto","x":[38.61519241],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[126511.1641],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[222688.2344],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[35871.94141],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"h","showlegend":true,"textposition":"auto","x":[4016.146484],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=United States<br>1990 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[802053.5923],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":" ...

# %% [markdown]
# 2018

# %%
df_2010_urban = df.query("Year == 2010").query("indicator == 'AG.LND.TOTL.UR.K2'")
df_2010_urban.rename(columns = {"value":"AG.LND.TOTL.UR.K2"}, inplace=True)
df_2010_urban.drop(['indicator','Region', 'Income Group', 'Lending Type'], axis = 1, inplace=True)
df_2010_urban.reset_index(drop=True,inplace=True)

df_2010_urban
# Out:
#    Unnamed: 0  Year  AG.LND.TOTL.UR.K2 Country Code   Country Name
# 0         292  2010       11125.391600          BGD     Bangladesh
# 1         295  2010          38.615192          BMU        Bermuda
# 2         298  2010      126511.164100          CAN         Canada
# 3         301  2010      222688.234400          IND          India
# 4         304  2010           0.000000          MDV       Maldives
# 5         307  2010       35871.941410          PAK       Pakistan
# 6         310  2010        4016.146484          LKA      Sri Lanka
# 7         313  2010      802053.592300          USA  United States

# %%
fig = px.bar(
    df_2010_urban, 
    x="AG.LND.TOTL.UR.K2",
    labels={"AG.LND.TOTL.UR.K2":"2010 Urban land area (sq.km)"},
    color="Country Name",
    height=800,
    title='Worldwide Urban land area (sq.km), 2010',
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="19f6cfb2-8e65-411e-9dc6-16cd5cc4a06b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19f6cfb2-8e65-411e-9dc6-16cd5cc4a06b")) {                    Plotly.newPlot(                        "19f6cfb2-8e65-411e-9dc6-16cd5cc4a06b",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=Bangladesh<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"h","showlegend":true,"textposition":"auto","x":[11125.3916],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Bermuda<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Bermuda","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"h","showlegend":true,"textposition":"auto","x":[38.61519241],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Canada<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[126511.1641],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=India<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[222688.2344],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Maldives<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Maldives","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Maldives","offsetgroup":"Maldives","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Pakistan<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"h","showlegend":true,"textposition":"auto","x":[35871.94141],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=Sri Lanka<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"h","showlegend":true,"textposition":"auto","x":[4016.146484],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=United States<br>2010 Urban land area (sq.km)=%{x}<br>index=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[802053.5923],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":" ...

# %% [markdown]
# # 📖 Observations:
#
# 🔎 Distributional changes in CO2 emissions, Forest area and Urban Land area are observed over the years.
#
# 🔎 The bar plot shows very little change in urban area over the years.
#
# 🔎 The relation between CO2 emissions and Forest cover changes for different countries. For example United States has some of the best forest cover, but also the most CO2 emissions. If we consider Canada it's not the same, It has the best forest cover but comparatively less CO2 emissions than the United states. Are the emissions less due to good forest cover? Probably yes.
